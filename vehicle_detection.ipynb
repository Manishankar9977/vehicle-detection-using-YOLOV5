# %%
# !pip install utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/vehicledetection/dataset.zip -d ../

# %%
# Train YOLOv5s on COCO128 for 3 epochs 9
# !python train.py --img 415 --batch 5 --epochs 300 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# 2023-04-08 10:04:23.895639: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-08 10:04:24.814271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 196 --conf 0.25 --source /content/aa1.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/aa1.jpg, data=data/coco128.yaml, imgsz=[196, 196], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ --img-size [196, 196] must be multiple of max stride 32, updating to [224, 224]
# image 1/1 /content/aa1.jpg: 160x224 3 lorrys, 35.8ms
# Speed: 0.3ms pre-process, 35.8ms inference, 76.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/exp2

# %%
# !python export.py --weights /content/damagedtree.pt --include tflite --img 416
# Out:
# export: data=data/coco128.yaml, weights=['/content/damagedtree.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v6.2-165-g966b0e0 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/damagedtree.pt with output shape (1, 10647, 6) (13.6 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.2...
#
#                  from  n    params  module                                  arguments
# 2022-09-25 16:25:09.983081: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !python detect.py --weights /content/damagedtree-fp16.tflite --img 416 --conf 0.25 --source /content/2.jpg
# Out:
# detect: weights=['/content/damagedtree-fp16.tflite'], source=/content/2.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-165-g966b0e0 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Loading /content/damagedtree-fp16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# image 1/1 /content/2.jpg: 416x416 4 damageds, 215.3ms
# Speed: 3721.6ms pre-process, 215.3ms inference, 1.8ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp3
